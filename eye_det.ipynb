# %%
import os
import PIL.Image as piImg
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mp
import shutil

# %%
url = 'C:/Users/M/Downloads/153.반려동물 안구질환 데이터/01.데이터/1.Training/라벨링데이터/TL2/고양이/안구/일반/cat_eyes_ci'

# %%
train_dir = os.path.join(url, 'train')
test_dir = os.path.join(url, 'test')
val_dir = os.path.join(url, 'val')

# %%
os.mkdir(train_dir)
os.mkdir(test_dir)
os.mkdir(val_dir)

# %%
train_corneal_ulcer_dir = os.path.join(train_dir, 'corneal_ulcer')
train_corneal_flap_dir = os.path.join(train_dir, 'corneal_flap')
train_conjunctivitis_dir = os.path.join(train_dir, 'conjunctivitis')
train_keratitis_dir = os.path.join(train_dir, 'keratitis')
train_blepharitis_dir = os.path.join(train_dir, 'blepharitis')
train_normal_dir = os.path.join(train_dir, 'normal')

test_corneal_ulcer_dir = os.path.join(test_dir, 'corneal_ulcer')
test_corneal_flap_dir = os.path.join(test_dir, 'corneal_flap')
test_conjunctivitis_dir = os.path.join(test_dir, 'conjunctivitis')
test_keratitis_dir = os.path.join(test_dir, 'keratitis')
test_blepharitis_dir = os.path.join(test_dir, 'blepharitis')
test_normal_dir = os.path.join(test_dir, 'normal')

val_corneal_ulcer_dir = os.path.join(val_dir, 'corneal_ulcer')
val_corneal_flap_dir = os.path.join(val_dir, 'corneal_flap')
val_conjunctivitis_dir = os.path.join(val_dir, 'conjunctivitis')
val_keratitis_dir = os.path.join(val_dir, 'keratitis')
val_blepharitis_dir = os.path.join(val_dir, 'blepharitis')
val_normal_dir = os.path.join(val_dir, 'normal')

# %%
os.mkdir(train_corneal_ulcer_dir)
os.mkdir(train_corneal_flap_dir)
os.mkdir(train_conjunctivitis_dir)
os.mkdir(train_keratitis_dir)
os.mkdir(train_blepharitis_dir)
os.mkdir(train_normal_dir)

os.mkdir(test_corneal_ulcer_dir)
os.mkdir(test_corneal_flap_dir)
os.mkdir(test_conjunctivitis_dir)
os.mkdir(test_keratitis_dir)
os.mkdir(test_blepharitis_dir)
os.mkdir(test_normal_dir)

os.mkdir(val_corneal_ulcer_dir)
os.mkdir(val_corneal_flap_dir)
os.mkdir(val_conjunctivitis_dir)
os.mkdir(val_keratitis_dir)
os.mkdir(val_blepharitis_dir)
os.mkdir(val_normal_dir)

# %%
corneal_ulcer_file = os.listdir(url + '/corneal_ulcer')[:950]
corneal_flap_file = os.listdir(url + '/corneal_flap')[:950]
conjunctivitis_file = os.listdir(url + '/conjunctivitis')[:950]
keratitis_file = os.listdir(url + '/keratitis')[:950]
blepharitis_file = os.listdir(url + '/blepharitis')[:950]
normal_file = os.listdir(url + '/normal')[:950]

# %%
print(len(corneal_ulcer_file), len(corneal_flap_file),len(conjunctivitis_file),len(keratitis_file),len(blepharitis_file),len(normal_file))
# Out:
# 950 950 950 950 950 950

# %%
for f in corneal_ulcer_file[:700]:
    shutil.copy(url + '/corneal_ulcer/' + f, train_corneal_ulcer_dir)
for f in corneal_ulcer_file[700:850]:
    shutil.copy(url + '/corneal_ulcer/' + f, val_corneal_ulcer_dir)
for f in corneal_ulcer_file[850:]:
    shutil.copy(url + '/corneal_ulcer/' + f, test_corneal_ulcer_dir)

for f in corneal_flap_file[:700]:
    shutil.copy(url + '/corneal_flap/' + f, train_corneal_flap_dir)
for f in corneal_flap_file[700:850]:
    shutil.copy(url + '/corneal_flap/' + f, val_corneal_flap_dir)
for f in corneal_flap_file[850:]:
    shutil.copy(url + '/corneal_flap/' + f, test_corneal_flap_dir)

for f in conjunctivitis_file[:700]:
    shutil.copy(url + '/conjunctivitis/' + f, train_conjunctivitis_dir)
for f in conjunctivitis_file[700:850]:
    shutil.copy(url + '/conjunctivitis/' + f, val_conjunctivitis_dir)    
for f in conjunctivitis_file[850:]:
    shutil.copy(url + '/conjunctivitis/' + f, test_conjunctivitis_dir)

for f in keratitis_file[:700]:
    shutil.copy(url + '/keratitis/' + f, train_keratitis_dir)
for f in keratitis_file[700:850]:
    shutil.copy(url + '/keratitis/' + f, val_keratitis_dir)
for f in keratitis_file[850:]:
    shutil.copy(url + '/keratitis/' + f, test_keratitis_dir)

for f in blepharitis_file[:700]:
    shutil.copy(url + '/blepharitis/' + f, train_blepharitis_dir)
for f in blepharitis_file[700:850]:
    shutil.copy(url + '/blepharitis/' + f, val_blepharitis_dir)
for f in blepharitis_file[850:]:
    shutil.copy(url + '/blepharitis/' + f, test_blepharitis_dir)

for f in normal_file[:700]:
    shutil.copy(url + '/normal/' + f, train_normal_dir)
for f in normal_file[700:850]:
    shutil.copy(url + '/normal/' + f, val_normal_dir)
for f in normal_file[850:]:
    shutil.copy(url + '/normal/' + f, test_normal_dir)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential,Model

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data_importer = train_datagen.flow_from_directory(
    url+'/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_data_importer = train_datagen.flow_from_directory(
    url+'/val',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_data_importer = train_datagen.flow_from_directory(
    url+'/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 4200 images belonging to 6 classes.
# Found 900 images belonging to 6 classes.
# Found 600 images belonging to 6 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def identity_block(input_tensor, filters, kernel_size):
    filters1, filters2, filters3 = filters

    x = layers.Conv2D(filters1, (1, 1), kernel_initializer='he_normal')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same', kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1), kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def conv_block(input_tensor, filters, kernel_size, strides=(2, 2)):
    filters1, filters2, filters3 = filters

    x = layers.Conv2D(filters1, (1, 1), strides=strides, kernel_initializer='he_normal')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same', kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1), kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)

    shortcut = layers.Conv2D(filters3, (1, 1), strides=strides, kernel_initializer='he_normal')(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def resnet50():
    input = layers.Input(shape=(224, 224, 3))
    x = layers.ZeroPadding2D((3, 3))(input)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = conv_block(x, [64, 64, 256], (3, 3), strides=(1, 1))
    x = identity_block(x, [64, 64, 256], (3, 3))
    x = identity_block(x, [64, 64, 256], (3, 3))

    x = conv_block(x, [128, 128, 512], (3, 3))
    x = identity_block(x, [128, 128, 512], (3, 3))
    x = identity_block(x, [128, 128, 512], (3, 3))
    x = identity_block(x, [128, 128, 512], (3, 3))

    x = conv_block(x, [256, 256, 1024], (3, 3))
    x = identity_block(x, [256, 256, 1024], (3, 3))
    x = identity_block(x, [256, 256, 1024], (3, 3))
    x = identity_block(x, [256, 256, 1024], (3, 3))
    x = identity_block(x, [256, 256, 1024], (3, 3))
    x = identity_block(x, [256, 256, 1024], (3, 3))

    x = conv_block(x, [512, 512, 2048], (3, 3))
    x = identity_block(x, [512, 512, 2048], (3, 3))
    x = identity_block(x, [512, 512, 2048], (3, 3))

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(5, activation='softmax')(x)

    model = models.Model(inputs=input, outputs=x)
    return model

model = resnet50()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 230, 230,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      9,472 │ zero_padding2d[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(
    train_data_importer,
    epochs=5,
    validation_data=val_data_importer
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 hist = model.fit(
#       2     train_data_importer,
#       3     epochs=5,
#       4     validation_data=val_data_importer
#       5 )
#
# File c:\Users\M\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\M\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\nn.py:561, in categorical_crossentropy(target, output, from_logits, axis)
# ...

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(224, 224, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='softmax'))
model.summary()
# Out:
# c:\Users\M\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(
    train_data_importer,
    epochs=10,
    validation_data=val_data_importer
)
# Out:
# Epoch 1/10
# c:\Users\M\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 53s 375ms/step - accuracy: 0.1850 - loss: 1.7927 - val_accuracy: 0.2078 - val_loss: 1.7386
# Epoch 2/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 48s 360ms/step - accuracy: 0.2754 - loss: 1.6920 - val_accuracy: 0.3467 - val_loss: 1.6051
# Epoch 3/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 48s 363ms/step - accuracy: 0.3496 - loss: 1.5637 - val_accuracy: 0.3789 - val_loss: 1.5344
# Epoch 4/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 48s 361ms/step - accuracy: 0.4077 - loss: 1.4652 - val_accuracy: 0.3844 - val_loss: 1.5179
# Epoch 5/10
# ...

# %%
model2 = Sequential()
model2.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                    activation ='relu', input_shape = (224, 224, 3)))
model2.add(Conv2D(filters = 32, kernel_size = (3,3),padding = 'Same', 
                    activation ='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())
model2.add(Dropout(0.25))
model2.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                    activation ='relu'))
model2.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                    activation ='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())
model2.add(Dropout(0.25))
model2.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                    activation ='relu'))
model2.add(Conv2D(filters = 86, kernel_size = (3,3),padding = 'Same', 
                    activation ='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())
model2.add(Dropout(0.25))
model2.add(Flatten())
model2.add(Dense(1024, activation = "relu"))
model2.add(Dropout(0.5))
model2.add(Dense(512, activation = "relu"))
model2.add(Dropout(0.5))
model2.add(Dense(6, activation = "softmax"))
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 224, 224, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model2.fit(
    train_data_importer,
    epochs=10,
    validation_data=val_data_importer
)
# Out:
# Epoch 1/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.1980 - loss: 10.0808 - val_accuracy: 0.1667 - val_loss: 4.8658
# Epoch 2/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.2371 - loss: 1.9695 - val_accuracy: 0.1667 - val_loss: 6.4152
# Epoch 3/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 363s 3s/step - accuracy: 0.2530 - loss: 1.7379 - val_accuracy: 0.1711 - val_loss: 1.9298
# Epoch 4/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 338s 3s/step - accuracy: 0.2736 - loss: 1.6946 - val_accuracy: 0.1900 - val_loss: 2.6805
# Epoch 5/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 337s 3s/step - accuracy: 0.2946 - loss: 1.6469 - val_accuracy: 0.2822 - val_loss: 1.6392
# Epoch 6/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 345s 3s/step - accuracy: 0.3221 - loss: 1.6196 - val_accuracy: 0.3500 - val_loss: 1.6062
# Epoch 7/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 339s 3s/step - accuracy: 0.3487 - loss: 1.5788 - val_accuracy: 0.3144 - val_loss: 1.5910
# Epoch 8/10
# ...

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
resnet = ResNet50(weights='imagenet', include_top=False)

# ResNet50 레이어의 파라미터를 학습하지 않도록 설정
# 역전파를 통해 오차 정보가 전파 되더라도 파라미터가 업데이트되지 않는다.
for layer in resnet.layers:
    layer.trainable = False

# Fully connected layer 추가
x = resnet.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(6, activation='sigmoid')(x)
model3 = Model(resnet.input, predictions)
model3.summary()
# Out:
# Model: "functional_32"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, None,      │          0 │ input_layer_3[0]… │
# │ (ZeroPadding2D)     │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, None,      │      9,472 │ conv1_pad[0][0]   │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model3.fit(
    train_data_importer,
    epochs=10,
    validation_data=val_data_importer
)
# Out:
# Epoch 1/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.1820 - loss: 1.9958 - val_accuracy: 0.1900 - val_loss: 1.8421
# Epoch 2/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.2160 - loss: 1.8034 - val_accuracy: 0.2378 - val_loss: 1.7466
# Epoch 3/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.2275 - loss: 1.7572 - val_accuracy: 0.2433 - val_loss: 1.7501
# Epoch 4/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.2194 - loss: 1.7520 - val_accuracy: 0.2478 - val_loss: 1.7344
# Epoch 5/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.2402 - loss: 1.7422 - val_accuracy: 0.2211 - val_loss: 1.7521
# Epoch 6/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.2361 - loss: 1.7461 - val_accuracy: 0.2389 - val_loss: 1.7413
# Epoch 7/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - accuracy: 0.2536 - loss: 1.7334 - val_accuracy: 0.2222 - val_loss: 1.7427
# Epoch 8/10
# ...

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, Activation, add, \
                          Activation, Flatten, Dense, GlobalAveragePooling2D, Reshape, multiply, concatenate, Dropout, multiply

# %%
def Residual_Block(x, filters):
  x_skip = x
  f = filters

  x = Conv2D(f, (3,3), padding='same')(x)
  x = BatchNormalization(axis=3)(x)
  x = Activation('relu')(x)

  x = Conv2D(f, (3,3), padding='same')(x)
  x = BatchNormalization(axis=3)(x)
  x = Activation('relu')(x)

  x_skip = Conv2D(f, (1,1), strides=(1,1,))(x_skip)
  x_skip = BatchNormalization(axis=3)(x_skip)

  x = add([x, x_skip])
  x = Activation('relu')(x)

  return x

# %%
def Residual_Block_50(x, filters):
  x_skip = x
  f1, f2 = filters

  x = Conv2D(f1, (1,1), padding='same')(x)
  x = BatchNormalization(axis=3)(x)
  x = Activation('relu')(x)

  x = Conv2D(f1, (3,3), padding='same')(x)
  x = BatchNormalization(axis=3)(x)
  x = Activation('relu')(x)

  x = Conv2D(f2, (1,1), padding='same')(x)
  x = BatchNormalization(axis=3)(x)
  x = Activation('relu')(x)

  x_skip = Conv2D(f2, (1,1), strides=(1,1,))(x_skip)
  x_skip = BatchNormalization(axis=3)(x_skip)

  x = add([x, x_skip])
  x = Activation('relu')(x)

  return x

# %%
input = Input(shape = (224,224,3))

x = Conv2D(64, (7,7), strides=(2,2), padding='same')(input)
x = MaxPooling2D((3,3), strides=(2,2), padding='same')(x)

for i in range(3):
  x = Residual_Block_50(x, [64, 256])

for i in range(4):
  x = Residual_Block_50(x, [128, 512])

for i in range(6):
  x = Residual_Block_50(x, [256, 1024])

for i in range(3):
  x = Residual_Block_50(x, [512, 2048])

x = Residual_Block(x, filters=64)
x = Residual_Block(x, filters=64)

x = Residual_Block(x, filters=128)
x = Residual_Block(x, filters=128)

x = Residual_Block(x, filters=256)
x = Residual_Block(x, filters=256)

x = Residual_Block(x, filters=512)
x = Residual_Block(x, filters=512)

x = GlobalAveragePooling2D()(x)

x = Dense(6, activation='softmax')(x)

model4 = Model(inputs = input, outputs = x)
model4.summary()

# %%
model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model4.fit(
    train_data_importer,
    epochs=5,
    validation_data=val_data_importer
)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0

def build_efficientnet(input_shape=(224, 224, 3), num_classes=5):
    base_model = EfficientNetB0(include_top=False, input_shape=input_shape, weights='imagenet')
    base_model.trainable = False  # 사전 학습된 가중치를 고정

    inputs = layers.Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

model = build_efficientnet()
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_6      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(
    train_data_importer,
    epochs=5,
    validation_data=val_data_importer
)
# Out:
# Epoch 1/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 87s 691ms/step - accuracy: 0.1933 - loss: 1.6191 - val_accuracy: 0.2000 - val_loss: 1.6122
# Epoch 2/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 72s 651ms/step - accuracy: 0.1968 - loss: 1.6136 - val_accuracy: 0.2000 - val_loss: 1.6100
# Epoch 3/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 71s 643ms/step - accuracy: 0.2154 - loss: 1.6112 - val_accuracy: 0.2000 - val_loss: 1.6103
# Epoch 4/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 72s 648ms/step - accuracy: 0.2003 - loss: 1.6108 - val_accuracy: 0.2000 - val_loss: 1.6094
# Epoch 5/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 78s 706ms/step - accuracy: 0.2039 - loss: 1.6095 - val_accuracy: 0.2000 - val_loss: 1.6095

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def mbconv_block(input_tensor, filters, expand_ratio, kernel_size, strides, se_ratio):
    # Expansion phase
    in_channels = input_tensor.shape[-1]
    x = layers.Conv2D(int(in_channels * expand_ratio), (1, 1), padding='same', use_bias=False)(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # Depthwise Convolution
    x = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # Squeeze and Excitation
    se = layers.GlobalAveragePooling2D()(x)
    se = layers.Reshape((1, 1, int(in_channels * expand_ratio)))(se)
    se = layers.Dense(int(in_channels * expand_ratio * se_ratio), activation='swish')(se)
    se = layers.Dense(int(in_channels * expand_ratio), activation='sigmoid')(se)
    x = layers.multiply([x, se])

    # Output phase
    x = layers.Conv2D(filters, (1, 1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if strides == 1 and in_channels == filters:
        x = layers.add([x, input_tensor])
    
    return x

def build_efficientnet_custom(input_shape=(224, 224, 3), num_classes=5):
    inputs = layers.Input(shape=input_shape)
    # Stem
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)
    
    # MBConv blocks
    x = mbconv_block(x, filters=16, expand_ratio=1, kernel_size=(3, 3), strides=1, se_ratio=0.25)
    
    x = mbconv_block(x, filters=24, expand_ratio=6, kernel_size=(3, 3), strides=2, se_ratio=0.25)
    x = mbconv_block(x, filters=24, expand_ratio=6, kernel_size=(3, 3), strides=1, se_ratio=0.25)

    x = mbconv_block(x, filters=40, expand_ratio=6, kernel_size=(5, 5), strides=2, se_ratio=0.25)
    x = mbconv_block(x, filters=40, expand_ratio=6, kernel_size=(5, 5), strides=1, se_ratio=0.25)

    # Add more MBConv blocks as needed for EfficientNetB0

    # Final layers
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

model = build_efficientnet_custom()
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_267 (Conv2D) │ (None, 112, 112,  │        864 │ input_layer_10[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_267[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(
    train_data_importer,
    epochs=10,
    validation_data=val_data_importer
)
# Out:
# Epoch 1/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.4849 - loss: 1.2234 - val_accuracy: 0.3973 - val_loss: 1.3512
# Epoch 2/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.5107 - loss: 1.1763 - val_accuracy: 0.4293 - val_loss: 1.2732
# Epoch 3/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.5160 - loss: 1.1728 - val_accuracy: 0.4787 - val_loss: 1.2177
# Epoch 4/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.5388 - loss: 1.1176 - val_accuracy: 0.4320 - val_loss: 1.3228
# Epoch 5/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.5307 - loss: 1.1265 - val_accuracy: 0.4947 - val_loss: 1.2117
# Epoch 6/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.5580 - loss: 1.0585 - val_accuracy: 0.3827 - val_loss: 1.4621
# Epoch 7/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.5483 - loss: 1.0596 - val_accuracy: 0.4413 - val_loss: 1.4014
# Epoch 8/10
# ...
